# %%
import sys
import os
print(os.getcwd())
sys.path.append("/workspaces/scopingreview/llm_utils")

from llm_utils.llm_utils.resource.PubMedQuery import PubMedQueryGenerator
from ScopingReview_config import app_config

LLM_INTERFACE = AzureChatOpenAI(
    azure_endpoint="https://nlp-ai-svc.openai.azure.com/",
    openai_api_version="2024-02-01",
    deployment_name="ChatGPT4",
    openai_api_type="azure",
    temperature=0,
    model_name="gpt-4",
    openai_api_key = app_config.GPT4_KEY
)
# Out:
# /workspaces/scopingreview/explorations/pubmedAPI
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 6
#       3 print(os.getcwd())
#       4 sys.path.append("/workspaces/scopingreview/llm_utils")
# ----> 6 from llm_utils.llm_utils.resource.PubMedQuery import PubMedQueryGenerator
#       7 from ScopingReview_config import app_config
#       9 LLM_INTERFACE = AzureChatOpenAI(
#      10     azure_endpoint="https://nlp-ai-svc.openai.azure.com/",
#      11     openai_api_version="2024-02-01",
#    (...)
#      16     openai_api_key = app_config.GPT4_KEY
#      17 )
#
# File /workspaces/scopingreview/llm_utils/llm_utils/resource/PubMedQuery.py:1
# ----> 1 from llm_utils.generate.SingleResponse import SingleResponseHandler
#       2 from llm_utils.api.WorkflowHandler import WorkflowHandler
# ...

# %%
import llm_utils.llm_utils.generate
