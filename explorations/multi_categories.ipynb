# %%
import pandas as pd

# Sample DataFrame
data = {
    'article_id': [1, 2, 3],
    'title': ['Title1', 'Title2', 'Title3'],
    'categories': ['A, B, C', 'A, D', 'B, C']
}

# %%
df = pd.DataFrame(data)

# Step 1: Split 'categories' into lists
df['categories'] = df['categories'].str.split(', ')

# Step 2: Explode the DataFrame
df_exploded = df.explode('categories')

# %%
df_exploded.head()
# Out:
#    article_id   title categories
# 0           1  Title1          A
# 0           1  Title1          B
# 0           1  Title1          C
# 1           2  Title2          A
# 1           2  Title2          D
