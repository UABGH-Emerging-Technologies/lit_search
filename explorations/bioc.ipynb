# %%
pip install metapub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting metapub
#   Downloading metapub-0.5.5.tar.gz (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 2.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/site-packages (from metapub) (67.8.0)
# Collecting lxml
#   Downloading lxml-5.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 7.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.10/site-packages (from metapub) (2.31.0)
# Collecting eutils
#   Downloading eutils-0.6.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.1 MB/s eta 0:00:00
# Collecting habanero
#   Downloading habanero-1.2.6-py2.py3-none-any.whl (30 kB)
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting cssselect
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 3.8 MB/s eta 0:00:00a 0:00:01
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /home/vscode/.local/lib/python3.10/site-packages (from metapub) (1.16.0)
# Collecting tox
#   Downloading tox-4.13.0-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.0/155.0 kB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting pytest
#   Downloading pytest-8.0.2-py3-none-any.whl (333 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.0/334.0 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.25.0-py3-none-any.whl (9.4 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pytz in /home/vscode/.local/lib/python3.10/site-packages (from eutils->metapub) (2024.1)
# Requirement already satisfied: tqdm in /home/vscode/.local/lib/python3.10/site-packages (from habanero->metapub) (4.66.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests->metapub) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.10/site-packages (from requests->metapub) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests->metapub) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests->metapub) (3.3.2)
# Requirement already satisfied: tomli>=1.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from pytest->metapub) (2.0.1)
# Collecting pluggy<2.0,>=1.3.0
#   Downloading pluggy-1.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/vscode/.local/lib/python3.10/site-packages (from pytest->metapub) (1.2.0)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: packaging in /home/vscode/.local/lib/python3.10/site-packages (from pytest->metapub) (23.2)
# Collecting Levenshtein==0.25.0
#   Downloading Levenshtein-0.25.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 1.6 MB/s eta 0:00:0000:0100:01
# Collecting rapidfuzz<4.0.0,>=3.1.0
#   Downloading rapidfuzz-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 2.7 MB/s eta 0:00:0000:0100:01
# Collecting colorama>=0.4.6
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting chardet>=5.2
#   Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 5.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: platformdirs>=4.1 in /home/vscode/.local/lib/python3.10/site-packages (from tox->metapub) (4.2.0)
# Requirement already satisfied: cachetools>=5.3.2 in /home/vscode/.local/lib/python3.10/site-packages (from tox->metapub) (5.3.3)
# Collecting filelock>=3.13.1
#   Downloading filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting pyproject-api>=1.6.1
#   Downloading pyproject_api-1.6.1-py3-none-any.whl (12 kB)
# Collecting virtualenv>=20.25
#   Downloading virtualenv-20.25.1-py3-none-any.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting distlib<1,>=0.3.7
#   Downloading distlib-0.3.8-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.9/468.9 kB 5.0 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: metapub, docopt
#   Building wheel for metapub (setup.py) ... done
#   Created wheel for metapub: filename=metapub-0.5.5-py3-none-any.whl size=135353 sha256=b52f218d0dc640354873a11912546039973da495fdaa3bd41d37bf4b1e5d993c
#   Stored in directory: /home/vscode/.cache/pip/wheels/14/2f/e7/b1df60d116db48f981dc3a8b320c9ba2d27d2526d5bad3579d
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=f5222401bc3d9fa8bca9f9ad1c3ff2b89b3ce30a3a14e789f9a21da152c661e4
#   Stored in directory: /home/vscode/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built metapub docopt
# Installing collected packages: docopt, distlib, unidecode, tabulate, rapidfuzz, pyproject-api, pluggy, lxml, iniconfig, humanfriendly, filelock, cssselect, colorama, chardet, virtualenv, pytest, Levenshtein, habanero, eutils, coloredlogs, tox, python-Levenshtein, metapub
# Successfully installed Levenshtein-0.25.0 chardet-5.2.0 colorama-0.4.6 coloredlogs-15.0.1 cssselect-1.2.0 distlib-0.3.8 docopt-0.6.2 eutils-0.6.0 filelock-3.13.1 habanero-1.2.6 humanfriendly-10.0 iniconfig-2.0.0 lxml-5.1.0 metapub-0.5.5 pluggy-1.4.0 pyproject-api-1.6.1 pytest-8.0.2 python-Levenshtein-0.25.0 rapidfuzz-3.6.1 tabulate-0.9.0 tox-4.13.0 unidecode-1.3.8 virtualenv-20.25.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import metapub
from pathlib import Path
from urllib.request import urlretrieve
import PyPDF2

pmid = '24664660'

url = metapub.FindIt(pmid).url
urlretrieve(url, 'b5.pdf')
pdf_path = Path('b5.pdf')

print("Downloading from URL:", url)


def extract_text_from_pdf(pdf_path):
    text = ''
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        num_pages = len(reader.pages)
        for page_number in range(num_pages):
            page = reader.pages[page_number]
            text += page.extract_text()
    return text

pdf_path = 'b5.pdf'  
extracted_text = extract_text_from_pdf(pdf_path)

with open('b5.txt', 'w', encoding='utf-8') as file:
    file.write(extracted_text)

print("Extracted text has been stored in extracted_text.txt")
# Out:
# Downloading from URL: http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC3996114&blobtype=pdf
# Extracted text has been stored in extracted_text.txt
