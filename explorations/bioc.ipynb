# %%
pip install metapub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: metapub in /home/ksoundararajan/.local/lib/python3.10/site-packages (0.5.5)
# Requirement already satisfied: eutils in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (0.6.0)
# Requirement already satisfied: docopt in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (0.6.2)
# Requirement already satisfied: python-Levenshtein in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (0.25.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from metapub) (59.6.0)
# Requirement already satisfied: pytest in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (8.0.1)
# Requirement already satisfied: tox in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (4.13.0)
# Requirement already satisfied: coloredlogs in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (15.0.1)
# Requirement already satisfied: requests in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (2.31.0)
# Requirement already satisfied: unidecode in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (1.3.8)
# Requirement already satisfied: lxml in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (5.1.0)
# Requirement already satisfied: six in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (1.12.0)
# Requirement already satisfied: habanero in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (1.2.6)
# Requirement already satisfied: cssselect in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (1.2.0)
# Requirement already satisfied: tabulate in /home/ksoundararajan/.local/lib/python3.10/site-packages (from metapub) (0.9.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from coloredlogs->metapub) (10.0)
# Requirement already satisfied: pytz in /home/ksoundararajan/.local/lib/python3.10/site-packages (from eutils->metapub) (2023.4)
# Requirement already satisfied: tqdm in /home/ksoundararajan/.local/lib/python3.10/site-packages (from habanero->metapub) (4.66.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from requests->metapub) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from requests->metapub) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from requests->metapub) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from requests->metapub) (2023.11.17)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from pytest->metapub) (1.2.0)
# Requirement already satisfied: iniconfig in /home/ksoundararajan/.local/lib/python3.10/site-packages (from pytest->metapub) (2.0.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from pytest->metapub) (2.0.1)
# Requirement already satisfied: packaging in /home/ksoundararajan/.local/lib/python3.10/site-packages (from pytest->metapub) (23.2)
# Requirement already satisfied: pluggy<2.0,>=1.3.0 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from pytest->metapub) (1.4.0)
# Requirement already satisfied: Levenshtein==0.25.0 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from python-Levenshtein->metapub) (0.25.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.1.0 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from Levenshtein==0.25.0->python-Levenshtein->metapub) (3.6.1)
# Requirement already satisfied: virtualenv>=20.25 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from tox->metapub) (20.25.1)
# Requirement already satisfied: platformdirs>=4.1 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from tox->metapub) (4.2.0)
# Requirement already satisfied: filelock>=3.13.1 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from tox->metapub) (3.13.1)
# Requirement already satisfied: pyproject-api>=1.6.1 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from tox->metapub) (1.6.1)
# Requirement already satisfied: chardet>=5.2 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from tox->metapub) (5.2.0)
# Requirement already satisfied: cachetools>=5.3.2 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from tox->metapub) (5.3.2)
# Requirement already satisfied: colorama>=0.4.6 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from tox->metapub) (0.4.6)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/ksoundararajan/.local/lib/python3.10/site-packages (from virtualenv>=20.25->tox->metapub) (0.3.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyPDF2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: PyPDF2 in /home/ksoundararajan/.local/lib/python3.10/site-packages (3.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import metapub
from pathlib import Path
from urllib.request import urlretrieve
import PyPDF2

pmid = '22499900'

url = metapub.FindIt(pmid).url
urlretrieve(url, 'test1.pdf')
pdf_path = Path('test1.pdf')

print("Downloading from URL:", url)


def extract_text_from_pdf(pdf_path):
    text = ''
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        num_pages = len(reader.pages)
        for page_number in range(num_pages):
            page = reader.pages[page_number]
            text += page.extract_text()
    return text

pdf_path = 'test1.pdf'  
extracted_text = extract_text_from_pdf(pdf_path)

with open('extracted_text1.txt', 'w', encoding='utf-8') as file:
    file.write(extracted_text)

print("Extracted text has been stored in extracted_text.txt")
# Out:
# Downloading from URL: http://europepmc.org/backend/ptpmcrender.fcgi?accid=PMC3366686&blobtype=pdf
# Extracted text has been stored in extracted_text.txt
