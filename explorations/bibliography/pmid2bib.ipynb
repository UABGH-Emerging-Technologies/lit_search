# %%
from ScopingReview.utils import pmid2bibtex
import pandas as pd
from pathlib import Path
pmid_list = ['31645359',
'34505625',
'12369649',
'25315702',
'17905071',
'37625804',
'4282263',
'29875981',
'30037615'
]
df = pd.read_excel('/data/results/rcg_test/CategorizedArticles.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Author 1: Relevant Article? (Yes/No)  56 non-null     object
#  1   Author 2: Relevant Article? (Yes/No)  56 non-null     object
#  2   date_published                        56 non-null     object
#  3   title                                 56 non-null     object
#  4   keywords                              56 non-null     object
#  5   abstract                              56 non-null     object
#  6   PMID                                  56 non-null     int64
#  7   authors                               56 non-null     object
#  8   journal                               56 non-null     object
#  9   citation                              56 non-null     object
#  10  Relevant                              6 non-null      float64
# ...

# %%
def get_PMID_list(df):
    if 'PMID' in df.columns:
        return df['PMID'].astype(str).tolist()
    else:
        return "The dataframe doesn't contain a 'PMID' column."

# %%
pmid_list = get_PMID_list(df)

# %%
pmid_list = get_PMID_list(df)
print(pmid_list)
# Out:
# ['31645359', '34505625', '12369649', '25315702', '17905071', '37625804', '4282263', '29875981', '30037615', '12322808', '27483660', '9323952', '5246679', '17005202', '31283078', '38289217', '5661884', '4111217', '25773155', '220988', '6966810', '3951599', '4968806', '7801555', '18792977', '25587612', '3204609', '10986649', '1415042', '8441087', '26956723', '14173853', '13195421', '8859928', '5308364', '18354149', '18893366', '25790894', '35962499', '26045520', '4665094', '10886692', '18303107', '3433511', '31345830', '9786777', '11508165', '3679683', '30995704', '2800831', '16142887', '34083183', '15153354', '11555001', '21392863', '29342391']

# %%
bibtex = pmid2bibtex(pmid_list)
# Out:
# IndexError ['31645359', '34505625', '12369649', '25315702', '17905071', '37625804', '4282263', '29875981', '30037615', '12322808', '27483660', '9323952', '5246679', '17005202', '31283078', '38289217', '5661884', '4111217', '25773155', '220988', '6966810', '3951599', '4968806', '7801555', '18792977', '25587612', '3204609', '10986649', '1415042', '8441087', '26956723', '14173853', '13195421', '8859928', '5308364', '18354149', '18893366', '25790894', '35962499', '26045520', '4665094', '10886692', '18303107', '3433511', '31345830', '9786777', '11508165', '3679683', '30995704', '2800831', '16142887', '34083183', '15153354', '11555001', '21392863', '29342391']

# %%
def write_to_file(filename, text):
    path = Path(filename)
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(filename, 'w') as f:
        f.write(text)

# %%
filename = '/data/results/rcg_test/testing.bib'
write_to_file(filename,bibtex)
