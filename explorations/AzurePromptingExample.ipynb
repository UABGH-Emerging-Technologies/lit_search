# %%
from langchain_openai import AzureChatOpenAI
from langchain.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
import os

# %% [markdown]
# # GOAL: Take an abstract and assign it to one of three categories.

# %%
chat = AzureChatOpenAI(
    azure_endpoint="https://nlp-ai-svc.openai.azure.com/",
    openai_api_version="2023-06-01-preview",
    azure_deployment="ChatGPT4",
    openai_api_type="azure",
    temperature=0,
    model_name="gpt-4",
    api_key= os.environ.get("OPENAI_API_KEY")
)

# %%
from langchain.prompts import PromptTemplate

system_template = """ Help categorize the text file into either of the input categories given by the user and return 1 category as output."""


human_template = """
CONTEXT:
{context}

INPUT CATEGORIES:
{categories}

OUTPUT:
"""
system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)

# %%
categories = ["Brain Tumors", "Parkinson's Disease", "Migraine", "Stroke", "Alzheimer's Disease", "Peripheral Neuropathy", "Epilepsy"]

# %%
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])

# %%
folder_path = "data"
output = []

for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):  # Check if the file is a text file
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r') as file:
            print(file_path)
            data = file.read()
            result = chat.invoke(chat_prompt.format_prompt(categories=categories, context=data).to_messages())
            output.append(result.content)
# Out:
# data/b2.txt
# data/b4.txt
# data/b1.txt
# data/b3.txt
# data/b5.txt

# %%
print(output)
# Out:
# ['"Parkinson\'s Disease"', '"Alzheimer\'s Disease"', '"Parkinson\'s Disease"', '"Alzheimer\'s Disease"', "'Epilepsy'"]

# %%
from langchain.text_splitter import CharacterTextSplitter


# Create a RecursiveCharacterTextSplitter instance
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)

splitter.create_documents([data])
