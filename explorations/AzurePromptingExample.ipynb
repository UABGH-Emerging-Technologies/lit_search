# %%
! $(cat .streamlit/secrets.toml | xargs)
# Out:
# cat: .streamlit/secrets.toml: No such file or directory

# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 817.0/817.0 KB 5.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 KB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 13.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 KB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 KB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.5/239.5 KB 14.6 MB/s eta 0:00:00
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.6/301.6 KB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.3/124.3 KB 7.8 MB/s eta 0:00:00
# ...

# %%
from IPython.display import display, Markdown, HTML
# from langchain.vectorstores import FAISS
# from langchain.document_loaders import PyPDFLoader
# from langchain.embeddings import OpenAIEmbeddings
from langchain_openai import AzureChatOpenAI
from langchain.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
)
    
import os
import openai

# %% [markdown]
# # GOAL: Take an abstract and assign it to one of three categories.

# %%
print(os.environ.get("openai_api_key"))
# Out:
# None

# %%
#chat = ChatOpenAI(temperature=0, model_name="gpt-4", request_timeout=300)
chat = AzureChatOpenAI(
    azure_endpoint="https://nlp-ai-svc.openai.azure.com/",
    openai_api_version="2023-06-01-preview",
    azure_deployment="ChatGPT4",
    openai_api_type="azure",
    temperature=0,
    model_name="gpt-4",
    api_key= os.environ.get("OPENAI_API_KEY")
)
# embedding = OpenAIEmbeddings(
#                 deployment="AdaEmbedding2",
#                 model="text-embedding-ada-002",
#                 openai_api_base="https://nlp-openai-svc.openai.azure.com",
#                 openai_api_type="azure",
#                 openai_api_key="",
#                 chunk_size=1
#             )

# # Make vector store
# loader = PyPDFLoader("/home/rmelvin/test/resident-helper/ChatGPTSyntheticApplication.pdf")
# pages = loader.load_and_split()
# vectordb = FAISS.from_documents(pages, embedding)
# vectordb.save_local("faiss_index")
# Load vectorstore
#vectordb = FAISS.load_local("faiss_index", embedding)

# %%
print(os.environ.get("OPENAI_API_KEY"))
# Out:
# 4d6ccbb6ba9c469ca8593d9e7251f4de

# %%
from langchain.prompts import PromptTemplate

chat_template = """

Help categorize the text file into either of the 3 input categories given by the user. Return 1 category as output.

CONTEXT:
{context}

INPUT CATEGORIES:
{category1}, {category2}, {category3}  

OUTPUT:
"""
prompt_template = PromptTemplate(input_variables=["category1", "category2", "category3", "context"], template = chat_template)

print(prompt_template.format(category1="Cardiology",category2="Neurology",category3="Anesthesiology", context="extracted_text1.txt"))
# Out:
# Help categorize the text file into either of the 3 input categories given by the user. Return 1 category as output.
#
# CONTEXT:
# extracted_text1.txt
#
# INPUT CATEGORIES:
# Cardiology, Neurology, Anesthesiology
#
# OUTPUT:

# %%
print(chat(prompt_template))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(chat(prompt_template))
#
# File ~/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:691, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     683 @deprecated("0.1.7", alternative="invoke", removal="0.2.0")
#     684 def __call__(
#     685     self,
#    (...)
#     689     **kwargs: Any,
#     690 ) -> BaseMessage:
# --> 691     generation = self.generate(
#     692         [messages], stop=stop, callbacks=callbacks, **kwargs
#     693     ).generations[0][0]
# ...

# %%
from langchain.prompts import PromptTemplate

system_template = """ Help categorize the text file into either of the 3 input categories given by the user. Return 1 category as output."""

human_template = """
CONTEXT:
{context}

INPUT CATEGORIES:
{category1}, {category2}, {category3}  

OUTPUT:
"""
prompt_template = PromptTemplate(input_variables=["category1", "category2", "category3", "context"], template = chat_template)

print(prompt_template.format(category1="Cardiology",category2="Neurology",category3="Anesthesiology", context="extracted_text1.txt"))
# Out:
# Help categorize the text file into either of the 3 input categories given by the user. Return 1 category as output.
#
# CONTEXT:
# extracted_text1.txt
#
# INPUT CATEGORIES:
# Cardiology, Neurology, Anesthesiology
#
# OUTPUT:

# %%
system_message_prompt = SystemMessagePromptTemplate.from_template(system_template)

# %%
print(system_message_prompt)
# Out:
# prompt=PromptTemplate(input_variables=[], template=' Help categorize the text file into either of the 3 input categories given by the user. Return 1 category as output.')

# %%
human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)
chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])
result = chat(
chat_prompt.format_prompt(
    category1="Cardiology",category2="Neurology",category3="Anesthesiology", context="extracted_text1.txt"
).to_messages())
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[20], line 3
#       1 human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)
#       2 chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])
# ----> 3 result = chat(
#       4 chat_prompt.format_prompt(
#       5     category1="Cardiology",category2="Neurology",category3="Anesthesiology", context="extracted_text1.txt"
#       6 ).to_messages())
#
# File ~/.local/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# ...

# %%
print(result.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(result.content)
#
# NameError: name 'result' is not defined
